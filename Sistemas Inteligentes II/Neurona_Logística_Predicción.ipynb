# %% [markdown]
# <a href="https://colab.research.google.com/github/santana-robledo/Posgrado_Robotica_e_Inteligencia_Artificial/blob/main/Sistemas%20Inteligentes%20II/Neurona_Log%C3%ADstica_Predicci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Neurona Logística Predicción
# ## Josue Santana Robledo Corona

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
class Logistic_Neuron:

    def __init__(self, n_inputs, learning_rate=0.1):
        self.w = - 1 + 2 * np.random.rand(n_inputs)
        self.b = - 1 + 2 * np.random.rand()
        self.eta = learning_rate

    def predict_proba(self, X):
        Z = np.dot(self.w, X) + self.b
        Y_est = 1/(1+np.exp(-Z))
        return Y_est

    def predict(self, X, umbral=0.5):
        Z = np.dot(self.w, X) + self.b
        Y_est = 1/(1+np.exp(-Z))
        return 1 * (Y_est > umbral)

    def train(self, X, Y, epochs=100):
        p = X.shape[1]
        for _ in range(epochs):
            Y_est = self.predict_proba(X)
            self.w += (self.eta/p) * np.dot((Y - Y_est), X.T).ravel()
            self.b += (self.eta/p) * np.sum(Y - Y_est)

# %%
# Ejemplo
X = df[["Age", "Glucose","BMI","DiabetesPedigreeFunction","BloodPressure"]].values.T
Y = df["Outcome"].values
X= (X-X.mean(axis=1,keepdims=True)) / X.std(axis=1,keepdims=True)

neuron = Logistic_Neuron(5, 0.01)
neuron.train(X,Y,epochs=1000)

Y_hat = neuron.predict(X,0.5)
accuracy = np.mean(Y_hat == Y)*100
print(f"Accuracy: {accuracy:.2f} %")
# Out:
# Accuracy: 78.12 %

# %% [markdown]
# Conclusiones:
#
# Esta práctica estuvo interesante, lo primero que hice fu rescatar las funciones del script del cuadernillo de la Neurona Logística, y solo cambiar X y Y, con la ayuda de gemini descubri que tenía que usar values.T y que en una misma variable podía usar tantas variables como quisiera, mientras editara el numero de entradas en la funcion neuron, puse desde 2 hasta todas, y nunca subí de un Accuracy de 78, también vi lo importante de normalizar, ya que esto bajaba drasticamente la efectividad.
#
# El umbral se le modifica en Y_hat = neuron.predict(X,0.5), aunque por defecto ya tiene el umbral solicitado, y al final imprimimos el porcentaje de aciertos de la neurona
#
# Mi accuracy en mi primer intento fue de 0.3489583333333333
